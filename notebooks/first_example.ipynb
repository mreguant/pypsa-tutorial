# %% [markdown]
# <a href="https://colab.research.google.com/github/mreguant/pypsa-tutorial/blob/main/notebooks/first_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# @title
# 1. Install PyPSA
# !pip install pypsa

# 2. Install an open-source solver (GLPK is easiest for Colab)
# !apt-get install -y glpk-utils

# 3. (Optional) Install linopy (the library PyPSA uses for optimization)
# !pip install linopy

# %%
import pypsa
import pandas as pd

# %%
# 1. Create the Network
n = pypsa.Network()
n.add("Bus", "Market", v_nom=380)

# 2. Add Generators with different costs and capacities
# Costs are in EUR/MWh, capacity in MW
n.add("Generator", "Wind", bus="Market", p_nom=100, marginal_cost=0)
n.add("Generator", "Coal", bus="Market", p_nom=100, marginal_cost=30)
n.add("Generator", "Gas",  bus="Market", p_nom=100, marginal_cost=60)

# 3. Add a Load (Demand)
n.add("Load", "Demand", bus="Market", p_set=150)

# 4. Solve using 'highs' (a modern, fast open-source solver)
n.sanitize()
n.optimize(solver_name='highs')

# 5. Display Results
print("\n--- Dispatch Results (MW) ---")
print(n.generators_t.p)
# Out:
# /tmp/ipykernel_1579/1937501157.py:16: FutureWarning:
#
# The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
# --- Dispatch Results (MW) ---
# name       Wind  Coal  Gas
# snapshot
# now       100.0  50.0 -0.0
